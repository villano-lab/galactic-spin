# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../python')
import NGC5533_functions as nf
from noordermeer import *
import dataPython as dp

# %%
dat_import = dp.getXYZdata('rotmod_test-readable.dat')
r = dat_import['xx']
v_lib = nf.d_v(r,path='../fitting')
v_file = dat_import['zz']

new_dat_import = dp.getXYZdata('try3')
v_newfile = new_dat_import['zz']

# %%
plt.figure(figsize=(10,8))

plt.plot(r,v_lib,label='From Library')
plt.plot(r,v_file,label='From GIPSY (HI Density to DISK in ROTMOD)')
plt.plot(r,v_newfile,label='From GIPSY (Disk file)')
plt.plot(r_gas,v_gas,label='Gas Component from Noordermeer')
plt.plot(r_disk,v_disk,label='From Noordermeer')

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Note: I am currently using the HI density profile because I don't understand where I would find one for the disk.
